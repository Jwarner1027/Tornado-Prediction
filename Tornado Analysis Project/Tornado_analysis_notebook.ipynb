# %%
import altair as alt
import pandas as pd
import os

storm_data = []

recent_folder = "..\Tornado Analysis Project\Current DataSet"
historical_folder = "..\Tornado Analysis Project\Historical DataSet"

for filename in os.listdir(recent_folder):
    filepath = os.path.join(recent_folder, filename)
    data = pd.read_csv(filepath)
    storm_data.append(data)

for filename in os.listdir(historical_folder):
    filepath = os.path.join(historical_folder, filename)
    data = pd.read_csv(filepath)
    storm_data.append(data)


all_storm_data = pd.concat(storm_data, ignore_index=True)

all_storm_data.head()
# Out:
# C:\Users\Jwarn\AppData\Local\Temp\ipykernel_31544\3267535891.py:17: DtypeWarning: Columns (26,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(filepath)
# C:\Users\Jwarn\AppData\Local\Temp\ipykernel_31544\3267535891.py:17: DtypeWarning: Columns (26,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(filepath)
# C:\Users\Jwarn\AppData\Local\Temp\ipykernel_31544\3267535891.py:17: DtypeWarning: Columns (28) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(filepath)
# C:\Users\Jwarn\AppData\Local\Temp\ipykernel_31544\3267535891.py:17: DtypeWarning: Columns (28) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(filepath)
#    BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  END_TIME  \
# 0           201905          9        1554         201905        9      1830
# 1           201908          1           0         201908        7      1400
# 2           201909         25        1823         201909       25      1825
# 3           201902         19        2226         201902       19      2350
# 4           201902         19        2255         201902       19      2355
#
#    EPISODE_ID  EVENT_ID         STATE  STATE_FIPS  ...  END_RANGE END_AZIMUTH  \
# 0    137295.0    824116         TEXAS          48  ...        7.0         NNE
# 1    141502.0    849617  SOUTH DAKOTA          46  ...        3.0           W
# 2    141998.0    852808       ARIZONA           4  ...       24.0           S
# 3    134941.0    808922      ARKANSAS           5  ...        NaN         NaN
# 4    134941.0    808923      ARKANSAS           5  ...        NaN         NaN
#
#    END_LOCATION BEGIN_LAT  BEGIN_LON  END_LAT   END_LON  \
# 0  SAN GERONIMO   29.7898   -98.6406  29.7158  -98.7744
# 1         BRUCE   44.5400   -96.9600  44.4300  -96.9400
# 2      OCOTILLO   32.8700  -111.8800  32.8788 -111.8750
# 3           NaN       NaN        NaN      NaN       NaN
# 4           NaN       NaN        NaN      NaN       NaN
#
#                                    EPISODE_NARRATIVE  \
# 0  Thunderstorms developed along a cold front as ...
# 1  Minor flooding slowly dwindled during early Au...
# 2  Scattered thunderstorms developed over the cen...
# 3  Rain was heavy at times on the 19th, and there...
# 4  Rain was heavy at times on the 19th, and there...
#
#                                      EVENT_NARRATIVE DATA_SOURCE
# 0  Thunderstorms produced heavy rain that led to ...         CSV
# 1  A continuation of flooding from July, the Big ...         CSV
# 2  Scattered thunderstorms developed across the c...         CSV
# 3  One-quarter inch of freezing rain was measured...         CSV
# 4  One-quarter inch of freezing rain was measured...         CSV
#
# [5 rows x 51 columns]

# %%
all_storm_data.columns
# Out:
# Index(['BEGIN_YEARMONTH', 'BEGIN_DAY', 'BEGIN_TIME', 'END_YEARMONTH',
#        'END_DAY', 'END_TIME', 'EPISODE_ID', 'EVENT_ID', 'STATE', 'STATE_FIPS',
#        'YEAR', 'MONTH_NAME', 'EVENT_TYPE', 'CZ_TYPE', 'CZ_FIPS', 'CZ_NAME',
#        'WFO', 'BEGIN_DATE_TIME', 'CZ_TIMEZONE', 'END_DATE_TIME',
#        'INJURIES_DIRECT', 'INJURIES_INDIRECT', 'DEATHS_DIRECT',
#        'DEATHS_INDIRECT', 'DAMAGE_PROPERTY', 'DAMAGE_CROPS', 'SOURCE',
#        'MAGNITUDE', 'MAGNITUDE_TYPE', 'FLOOD_CAUSE', 'CATEGORY', 'TOR_F_SCALE',
#        'TOR_LENGTH', 'TOR_WIDTH', 'TOR_OTHER_WFO', 'TOR_OTHER_CZ_STATE',
#        'TOR_OTHER_CZ_FIPS', 'TOR_OTHER_CZ_NAME', 'BEGIN_RANGE',
#        'BEGIN_AZIMUTH', 'BEGIN_LOCATION', 'END_RANGE', 'END_AZIMUTH',
#        'END_LOCATION', 'BEGIN_LAT', 'BEGIN_LON', 'END_LAT', 'END_LON',
#        'EPISODE_NARRATIVE', 'EVENT_NARRATIVE', 'DATA_SOURCE'],
#       dtype='object')

# %%
import numpy as np
columns_to_keep = ['YEAR', 'MONTH_NAME', 'BEGIN_DAY', 'STATE','EVENT_TYPE', 'BEGIN_DATE_TIME',
                    'END_DATE_TIME', 'INJURIES_DIRECT', 'DEATHS_DIRECT', 'DAMAGE_PROPERTY',  'DAMAGE_CROPS', 'TOR_F_SCALE',
                      'TOR_LENGTH', 'TOR_WIDTH', 'BEGIN_RANGE', 'BEGIN_LAT', 'BEGIN_LON']

columns_to_drop = np.setdiff1d(all_storm_data.columns, columns_to_keep)

new_storms_data = all_storm_data[columns_to_keep]

new_storms_data.columns
# Out:
# Index(['YEAR', 'MONTH_NAME', 'BEGIN_DAY', 'STATE', 'EVENT_TYPE',
#        'BEGIN_DATE_TIME', 'END_DATE_TIME', 'INJURIES_DIRECT', 'DEATHS_DIRECT',
#        'DAMAGE_PROPERTY', 'DAMAGE_CROPS', 'TOR_F_SCALE', 'TOR_LENGTH',
#        'TOR_WIDTH', 'BEGIN_RANGE', 'BEGIN_LAT', 'BEGIN_LON'],
#       dtype='object')

# %%
tornado_df = new_storms_data[new_storms_data['EVENT_TYPE'] == 'Tornado']
tornado_df.count()
# Out:
# YEAR               15417
# MONTH_NAME         15417
# BEGIN_DAY          15417
# STATE              15417
# EVENT_TYPE         15417
# BEGIN_DATE_TIME    15417
# END_DATE_TIME      15417
# INJURIES_DIRECT    15417
# DEATHS_DIRECT      15417
# DAMAGE_PROPERTY    11152
# DAMAGE_CROPS        8469
# TOR_F_SCALE        15348
# TOR_LENGTH         15389
# TOR_WIDTH          15389
# BEGIN_RANGE        13646
# BEGIN_LAT          14893
# BEGIN_LON          14893
# dtype: int64

# %%
tornado_df.dtypes
# Out:
# YEAR                 int64
# MONTH_NAME          object
# BEGIN_DAY            int64
# STATE               object
# EVENT_TYPE          object
# BEGIN_DATE_TIME     object
# END_DATE_TIME       object
# INJURIES_DIRECT      int64
# DEATHS_DIRECT        int64
# DAMAGE_PROPERTY     object
# DAMAGE_CROPS        object
# TOR_F_SCALE         object
# TOR_LENGTH         float64
# TOR_WIDTH          float64
# BEGIN_RANGE        float64
# BEGIN_LAT          float64
# BEGIN_LON          float64
# dtype: object

# %%
tornado_df['BEGIN_DATE_TIME'] = tornado_df['BEGIN_DATE_TIME'].astype('datetime64[ns]')
tornado_df['END_DATE_TIME'] = tornado_df['END_DATE_TIME'].astype('datetime64[ns]')

tornado_df.head()
# Out:
# C:\Users\Jwarn\AppData\Local\Temp\ipykernel_31544\3969670697.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tornado_df['BEGIN_DATE_TIME'] = tornado_df['BEGIN_DATE_TIME'].astype('datetime64[ns]')
# C:\Users\Jwarn\AppData\Local\Temp\ipykernel_31544\3969670697.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tornado_df['END_DATE_TIME'] = tornado_df['END_DATE_TIME'].astype('datetime64[ns]')
#      YEAR MONTH_NAME  BEGIN_DAY      STATE EVENT_TYPE     BEGIN_DATE_TIME  \
# 2    2019  September         25    ARIZONA    Tornado 2019-09-25 18:23:00
# 5    2019        May         17   OKLAHOMA    Tornado 2019-05-17 18:32:00
# 25   2019     August          2      IDAHO    Tornado 2019-08-02 12:55:00
# 206  2019      April         24  LOUISIANA    Tornado 2019-04-24 23:11:00
# 243  2019      April         25  LOUISIANA    Tornado 2019-04-25 00:25:00
#
#           END_DATE_TIME  INJURIES_DIRECT  DEATHS_DIRECT DAMAGE_PROPERTY  \
# 2   2019-09-25 18:25:00                0              0           0.00K
# 5   2019-05-17 18:39:00                0              0           0.00K
# 25  2019-08-02 13:05:00                0              0           0.00K
# 206 2019-04-24 23:28:00                1              0          30.00K
# 243 2019-04-25 00:26:00                0              0          25.00K
#
#     DAMAGE_CROPS TOR_F_SCALE  TOR_LENGTH  TOR_WIDTH  BEGIN_RANGE  BEGIN_LAT  \
# 2          0.00K         EF0        0.67       50.0         24.0    32.8700
# 5          0.00K         EFU        2.88       50.0          5.0    36.9622
# 25         0.00K         EF0        1.00       10.0         12.0    42.6165
# 206        0.00K         EF1       10.00      900.0          3.0    31.8455
# 243        0.00K         EF1        1.03      200.0          1.0    32.3550
#
#      BEGIN_LON
# 2    -111.8800
# 5    -100.5635
# 25   -113.5521
# 206   -93.6039
# 243   -92.9253

# %% [markdown]
# 'BEGIN_DAY', 'BEGIN_TIME', 'END_DAY', 'END_TIME', 'STATE', 'YEAR', 'MONTH_NAME', 'EVENT_TYPE', 'BEGIN_DATE_TIME', 'END_DATE_TIME', 'INJURIES_DIRECT', 'DEATHS_DIRECT', 'DAMAGE_PROPERTY',  'DAMAGE_CROPS', 'MAGNITUDE', 'TOR_F_SCALE', 'TOR_LENGTH', 'TOR_WIDTH', 'BEGIN_RANGE', 'BEGIN_LAT', 'BEGIN_LON'

# %%
tornado_df.dtypes
# Out:
# YEAR                        int64
# MONTH_NAME                 object
# BEGIN_DAY                   int64
# STATE                      object
# EVENT_TYPE                 object
# BEGIN_DATE_TIME    datetime64[ns]
# END_DATE_TIME      datetime64[ns]
# INJURIES_DIRECT             int64
# DEATHS_DIRECT               int64
# DAMAGE_PROPERTY            object
# DAMAGE_CROPS               object
# TOR_F_SCALE                object
# TOR_LENGTH                float64
# TOR_WIDTH                 float64
# BEGIN_RANGE               float64
# BEGIN_LAT                 float64
# BEGIN_LON                 float64
# dtype: object

# %%
tornado_df.count()

tornado_df.isna().sum()
# Out:
# YEAR                  0
# MONTH_NAME            0
# BEGIN_DAY             0
# STATE                 0
# EVENT_TYPE            0
# BEGIN_DATE_TIME       0
# END_DATE_TIME         0
# INJURIES_DIRECT       0
# DEATHS_DIRECT         0
# DAMAGE_PROPERTY    4265
# DAMAGE_CROPS       6948
# TOR_F_SCALE          69
# TOR_LENGTH           28
# TOR_WIDTH            28
# BEGIN_RANGE        1771
# BEGIN_LAT           524
# BEGIN_LON           524
# dtype: int64

# %%
historical_df = tornado_df[tornado_df['YEAR'].isin([1995,1996, 1997,1998 ,1999, 2000])]

recent_df = tornado_df[tornado_df['YEAR'].isin([2019, 2020,2021 ,2022, 2023, 2024])]

# %%
monthly_counts_historical = historical_df.groupby([tornado_df['YEAR'], historical_df['MONTH_NAME']]).size()
historical_averages = monthly_counts_historical.to_frame(name='count').reset_index()
yearly_averages_historical = historical_averages.groupby(['MONTH_NAME']).mean('count')

monthly_counts_recent = recent_df.groupby([tornado_df['YEAR'], recent_df['MONTH_NAME']]).size()
recent_averages = monthly_counts_recent.to_frame(name='count').reset_index()
yearly_averages_recent = recent_averages.groupby(['MONTH_NAME']).mean('count')

yearly_averages_recent
# Out:
#               YEAR       count
# MONTH_NAME
# April       2021.0  242.600000
# August      2021.0  127.000000
# December    2021.0  115.600000
# February    2021.5   37.833333
# January     2021.5   66.833333
# July        2021.0  109.600000
# June        2021.0  158.800000
# March       2021.0  193.600000
# May         2021.0  291.000000
# November    2021.0   33.800000
# October     2021.0   66.000000
# September   2021.0   42.400000

# %%
base_chart = alt.Chart()

# Define line for historical data
historical_line = base_chart.mark_line().encode(
  x='Month:N',
  y='Average Tornadoes (Historical):Q',
  color='blue',  # Optional: Set color for historical line
)

# Define line for recent data (similar structure)
recent_line = base_chart.mark_line().encode(
  x='Month:N',
  y='Average Tornadoes (Recent):Q',
  color='red'  # Optional: Set color for recent line
)

# Combine the lines into a single chart
chart = alt.layer(historical_line, recent_line)


chart
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\Jwarn\anaconda3\anaconda\lib\site-packages\altair\vegalite\v5\api.py:961, in TopLevelMixin.to_dict(self, validate, format, ignore, context)
#     956 context["top_level"] = False
#     958 # TopLevelMixin instance does not necessarily have to_dict defined
#     959 # but due to how Altair is set up this should hold.
#     960 # Too complex to type hint right now
# --> 961 vegalite_spec = super(TopLevelMixin, copy).to_dict(  # type: ignore[misc]
#     962     validate=validate, ignore=ignore, context=dict(context, pre_transform=False)
#     963 )
#     965 # TODO: following entries are added after validation. Should they be validated?
#     966 if is_top_level:
#     967     # since this is top-level we add $schema if it's missing
#
# File c:\Users\Jwarn\anaconda3\anaconda\lib\site-packages\altair\utils\schemapi.py:960, in SchemaBase.to_dict(self, validate, ignore, context)
#     958     if "mark" in kwds and isinstance(kwds["mark"], str):
#     959         kwds["mark"] = {"type": kwds["mark"]}
# --> 960     result = _todict(
#     961         kwds,
#     962         context=context,
#     963     )
#     964 else:
#     965     raise ValueError(
#     966         "{} instance has both a value and properties : "
#     967         "cannot serialize to dict".format(self.__class__)
#     968     )
#
# File c:\Users\Jwarn\anaconda3\anaconda\lib\site-packages\altair\utils\schemapi.py:476, in _todict(obj, context)
#     474     return [_todict(v, context) for v in obj]
#     475 elif isinstance(obj, dict):
# --> 476     return {k: _todict(v, context) for k, v in obj.items() if v is not Undefined}
#     477 elif hasattr(obj, "to_dict"):
#     478     return obj.to_dict()
#
# File c:\Users\Jwarn\anaconda3\anaconda\lib\site-packages\altair\utils\schemapi.py:476, in <dictcomp>(.0)
#     474     return [_todict(v, context) for v in obj]
#     475 elif isinstance(obj, dict):
# --> 476     return {k: _todict(v, context) for k, v in obj.items() if v is not Undefined}
#     477 elif hasattr(obj, "to_dict"):
#     478     return obj.to_dict()
#
# File c:\Users\Jwarn\anaconda3\anaconda\lib\site-packages\altair\utils\schemapi.py:474, in _todict(obj, context)
#     472     return obj.to_dict(validate=False, context=context)
#     473 elif isinstance(obj, (list, tuple, np.ndarray)):
# --> 474     return [_todict(v, context) for v in obj]
#     475 elif isinstance(obj, dict):
#     476     return {k: _todict(v, context) for k, v in obj.items() if v is not Undefined}
#
# File c:\Users\Jwarn\anaconda3\anaconda\lib\site-packages\altair\utils\schemapi.py:474, in <listcomp>(.0)
#     472     return obj.to_dict(validate=False, context=context)
#     473 elif isinstance(obj, (list, tuple, np.ndarray)):
# --> 474     return [_todict(v, context) for v in obj]
#     475 elif isinstance(obj, dict):
#     476     return {k: _todict(v, context) for k, v in obj.items() if v is not Undefined}
#
# File c:\Users\Jwarn\anaconda3\anaconda\lib\site-packages\altair\utils\schemapi.py:472, in _todict(obj, context)
#     470 """Convert an object to a dict representation."""
#     471 if isinstance(obj, SchemaBase):
# --> 472     return obj.to_dict(validate=False, context=context)
#     473 elif isinstance(obj, (list, tuple, np.ndarray)):
#     474     return [_todict(v, context) for v in obj]
#
# File c:\Users\Jwarn\anaconda3\anaconda\lib\site-packages\altair\vegalite\v5\api.py:2972, in Chart.to_dict(self, validate, format, ignore, context)
#    2970     copy = self.copy(deep=False)
#    2971     copy.data = core.InlineData(values=[{}])  # type: ignore[assignment]
# -> 2972     return super(Chart, copy).to_dict(
#    2973         validate=validate, format=format, ignore=ignore, context=context
#    2974     )
#    2975 return super().to_dict(
#    2976     validate=validate, format=format, ignore=ignore, context=context
#    2977 )
#
# File c:\Users\Jwarn\anaconda3\anaconda\lib\site-packages\altair\vegalite\v5\api.py:961, in TopLevelMixin.to_dict(self, validate, format, ignore, context)
#     956 context["top_level"] = False
#     958 # TopLevelMixin instance does not necessarily have to_dict defined
#     959 # but due to how Altair is set up this should hold.
#     960 # Too complex to type hint right now
# --> 961 vegalite_spec = super(TopLevelMixin, copy).to_dict(  # type: ignore[misc]
#     962     validate=validate, ignore=ignore, context=dict(context, pre_transform=False)
#     963 )
#     965 # TODO: following entries are added after validation. Should they be validated?
#     966 if is_top_level:
#     967     # since this is top-level we add $schema if it's missing
#
# File c:\Users\Jwarn\anaconda3\anaconda\lib\site-packages\altair\utils\schemapi.py:960, in SchemaBase.to_dict(self, validate, ignore, context)
#     958     if "mark" in kwds and isinstance(kwds["mark"], str):
#     959         kwds["mark"] = {"type": kwds["mark"]}
# --> 960     result = _todict(
#     961         kwds,
#     962         context=context,
#     963     )
#     964 else:
#     965     raise ValueError(
#     966         "{} instance has both a value and properties : "
#     967         "cannot serialize to dict".format(self.__class__)
#     968     )
#
# File c:\Users\Jwarn\anaconda3\anaconda\lib\site-packages\altair\utils\schemapi.py:476, in _todict(obj, context)
#     474     return [_todict(v, context) for v in obj]
#     475 elif isinstance(obj, dict):
# --> 476     return {k: _todict(v, context) for k, v in obj.items() if v is not Undefined}
#     477 elif hasattr(obj, "to_dict"):
#     478     return obj.to_dict()
#
# File c:\Users\Jwarn\anaconda3\anaconda\lib\site-packages\altair\utils\schemapi.py:476, in <dictcomp>(.0)
#     474     return [_todict(v, context) for v in obj]
#     475 elif isinstance(obj, dict):
# --> 476     return {k: _todict(v, context) for k, v in obj.items() if v is not Undefined}
#     477 elif hasattr(obj, "to_dict"):
#     478     return obj.to_dict()
#
# File c:\Users\Jwarn\anaconda3\anaconda\lib\site-packages\altair\utils\schemapi.py:472, in _todict(obj, context)
#     470 """Convert an object to a dict representation."""
#     471 if isinstance(obj, SchemaBase):
# --> 472     return obj.to_dict(validate=False, context=context)
#     473 elif isinstance(obj, (list, tuple, np.ndarray)):
#     474     return [_todict(v, context) for v in obj]
#
# File c:\Users\Jwarn\anaconda3\anaconda\lib\site-packages\altair\utils\schemapi.py:960, in SchemaBase.to_dict(self, validate, ignore, context)
#     958     if "mark" in kwds and isinstance(kwds["mark"], str):
#     959         kwds["mark"] = {"type": kwds["mark"]}
# --> 960     result = _todict(
#     961         kwds,
#     962         context=context,
#     963     )
#     964 else:
#     965     raise ValueError(
#     966         "{} instance has both a value and properties : "
#     967         "cannot serialize to dict".format(self.__class__)
#     968     )
#
# File c:\Users\Jwarn\anaconda3\anaconda\lib\site-packages\altair\utils\schemapi.py:476, in _todict(obj, context)
#     474     return [_todict(v, context) for v in obj]
#     475 elif isinstance(obj, dict):
# --> 476     return {k: _todict(v, context) for k, v in obj.items() if v is not Undefined}
#     477 elif hasattr(obj, "to_dict"):
#     478     return obj.to_dict()
#
# File c:\Users\Jwarn\anaconda3\anaconda\lib\site-packages\altair\utils\schemapi.py:476, in <dictcomp>(.0)
#     474     return [_todict(v, context) for v in obj]
#     475 elif isinstance(obj, dict):
# --> 476     return {k: _todict(v, context) for k, v in obj.items() if v is not Undefined}
#     477 elif hasattr(obj, "to_dict"):
#     478     return obj.to_dict()
#
# File c:\Users\Jwarn\anaconda3\anaconda\lib\site-packages\altair\utils\schemapi.py:472, in _todict(obj, context)
#     470 """Convert an object to a dict representation."""
#     471 if isinstance(obj, SchemaBase):
# --> 472     return obj.to_dict(validate=False, context=context)
#     473 elif isinstance(obj, (list, tuple, np.ndarray)):
#     474     return [_todict(v, context) for v in obj]
#
# File c:\Users\Jwarn\anaconda3\anaconda\lib\site-packages\altair\vegalite\v5\schema\channels.py:73, in FieldChannelMixin.to_dict(self, validate, ignore, context)
#      64             raise ValueError(
#      65                 'Unable to determine data type for the field "{}";'
#      66                 " verify that the field name is not misspelled."
#    (...)
#      70                 )
#      71             )
#      72         else:
# ---> 73             raise ValueError(
#      74                 "{} encoding field is specified without a type; "
#      75                 "the type cannot be automatically inferred because "
#      76                 "the data is not specified as a pandas.DataFrame."
#      77                 "".format(shorthand)
#      78             )
#      79 else:
#      80     # Shorthand is not a string; we pass the definition to field,
#      81     # and do not do any parsing.
#      82     parsed = {"field": shorthand}
#
# ValueError: blue encoding field is specified without a type; the type cannot be automatically inferred because the data is not specified as a pandas.DataFrame.
# alt.LayerChart(...)
